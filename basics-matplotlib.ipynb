# %%
import matplotlib.pyplot as plt  #main plotting object
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52, 48, 49, 47, 53]

# %%
plt.xlabel('day')
plt.ylabel('temp')
plt.title('weather')
plt.plot(x,y,color='green',linewidth=5)
